# %% [markdown]
# <a href="https://colab.research.google.com/github/1234567890qqqqqq/BasicProg_DataViz65/blob/main/data1ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  # ใช้จัดการข้อมูลต่าง ๆ ที่เป็นตาราง พวกexcel ,CSV
from google.colab import drive # เชื่อม google drive กับ colab ของเรา นี้เป็นคำสั่งเชื่อม |accout colab กับ Drive ควรเป็น accout เดียวกัน|
drive.mount('/content/drive')
import os # การจัดเก็บเกี่ยวกับไฟล์ต่าง ๆ มันอยู่ที่โฟลเดอร์ไหน จะ list โฟล์เดอร์ออกมา
# Out:
# Mounted at /content/drive

# %%
data1= pd.read_excel('/content/drive/MyDrive/2 65/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='บ้าน',skiprows=1)
data1
# Out:
#      01     https://nayoo.co/khonkaen/posts/25  บ้านเดี่ยว  มั่นใจ  2700000.0  \
# 0     2     https://nayoo.co/khonkaen/posts/25  บ้านเดี่ยว  มั่นใจ  2700000.0
# 1     1     https://nayoo.co/khonkaen/posts/33  บ้านเดี่ยว  มั่นใจ  2600000.0
# 2     2     https://nayoo.co/khonkaen/posts/33  บ้านเดี่ยว  มั่นใจ  2600000.0
# 3     1    https://nayoo.co/khonkaen/posts/495  บ้านเดี่ยว  มั่นใจ  5900000.0
# 4     2    https://nayoo.co/khonkaen/posts/495  บ้านเดี่ยว  มั่นใจ  5900000.0
# ..   ..                                    ...         ...     ...        ...
# 184   2  https://nayoo.co/khonkaen/posts/19495  บ้านเดี่ยว  มั่นใจ  5500000.0
# 185   2  https://nayoo.co/khonkaen/posts/19496  บ้านเดี่ยว  มั่นใจ  7911000.0
# 186   2     https://nayoo.co/khonkaen/posts/20  บ้านเดี่ยว  มั่นใจ  2000000.0
# 187   2     https://nayoo.co/khonkaen/posts/31  บ้านเดี่ยว  มั่นใจ  4000000.0
# 188   2    https://nayoo.co/khonkaen/posts/570  บ้านเดี่ยว  มั่นใจ  1375000.0
#
# ...

# %%
data11 = data1[['Unnamed: 0','รวม','คะแนนร้อยละ40']]
data11

# %%
data2= pd.read_excel('/content/drive/MyDrive/2 65/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ที่ดิน',skiprows=1)
data2
# Out:
#      01   https://nayoo.co/khonkaen/posts/1033  ที่ดิน  มั่นใจ   2800000  \
# 0     2   https://nayoo.co/khonkaen/posts/1033  ที่ดิน  มั่นใจ   2800000
# 1     4   https://nayoo.co/khonkaen/posts/1033  ที่ดิน  มั่นใจ   2800000
# 2     1   https://nayoo.co/khonkaen/posts/1711  ที่ดิน  มั่นใจ  14900000
# 3     2   https://nayoo.co/khonkaen/posts/1711  ที่ดิน  มั่นใจ  14900000
# 4     4   https://nayoo.co/khonkaen/posts/1711  ที่ดิน  มั่นใจ  14900000
# ..   ..                                    ...     ...     ...       ...
# 204   1  https://nayoo.co/khonkaen/posts/17093  ที่ดิน  มั่นใจ   2650000
# 205   2  https://nayoo.co/khonkaen/posts/17112  ที่ดิน  มั่นใจ   1300000
# 206   1  https://nayoo.co/khonkaen/posts/17112  ที่ดิน  มั่นใจ   1300000
# 207   2  https://nayoo.co/khonkaen/posts/17145  ที่ดิน  มั่นใจ   3000000
# 208   1  https://nayoo.co/khonkaen/posts/17145  ที่ดิน  มั่นใจ   3000000
#
#       1800000.0                             8,000-25,000 Unnamed: 7  \
# ...

# %%
data3= pd.read_excel('/content/drive/MyDrive/2 65/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='คอนโด',skiprows=1)
data3
# Out:
#    01    32.0  คอนโด  มั่นใจ  3500000.0  3500000.0.1  \
# 0   1    36.0  คอนโด  มั่นใจ  1930000.0    2200000.0
# 1   1   603.0  คอนโด  มั่นใจ  2438000.0    2800000.0
# 2   1  1395.0  คอนโด  มั่นใจ  1600000.0    2300000.0
# 3   1  1443.0  คอนโด  มั่นใจ  1860000.0    1800000.0
# 4   1  1609.0  คอนโด  มั่นใจ  1490000.0    1500000.0
# 5   1  1640.0  คอนโด  มั่นใจ  1280000.0    1600000.0
# 6   1  1641.0  คอนโด  มั่นใจ  4290000.0    2700000.0
# 7   1  1650.0  คอนโด  มั่นใจ  1700000.0    1550000.0
# 8   1  1840.0  คอนโด  มั่นใจ  3790000.0    2800000.0
#
#    60,000-130,000 บาท/ตารางเมตร  Unnamed: 7  \
# 0   50,000-90,000 บาท/ตารางเมตร         NaN
# 1   35,000-80,000 บาท/ตารางเมตร         NaN
# 2   30,000-80,000 บาท/ตารางเมตร         NaN
# 3   30,000-80,000 บาท/ตารางเมตร         NaN
# 4   30,000-80,000 บาท/ตารางเมตร         NaN
# 5   30,000-70,000 บาท/ตารางเมตร         NaN
# 6  60,000-130,000 บาท/ตารางเมตร         NaN
# 7   30,000-70,000 บาท/ตารางเมตร         NaN
# ...

# %%
data4= pd.read_excel('/content/drive/MyDrive/2 65/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ทาวน์โฮม',skiprows=1)
data4
# Out:
#      01    https://nayoo.co/khonkaen/posts/548  ทาวน์โฮม  มั่นใจ  1045000.0  \
# 0     2    https://nayoo.co/khonkaen/posts/548  ทาวน์โฮม  มั่นใจ  1045000.0
# 1     1    https://nayoo.co/khonkaen/posts/549  ทาวน์โฮม  มั่นใจ   935000.0
# 2     2    https://nayoo.co/khonkaen/posts/549  ทาวน์โฮม  มั่นใจ   935000.0
# 3     1    https://nayoo.co/khonkaen/posts/579  ทาวน์โฮม  มั่นใจ  3520000.0
# 4     2    https://nayoo.co/khonkaen/posts/579  ทาวน์โฮม  มั่นใจ  3520000.0
# ..   ..                                    ...       ...     ...        ...
# 234   2  https://nayoo.co/khonkaen/posts/18547  ทาวน์โฮม  มั่นใจ  1430000.0
# 235   2  https://nayoo.co/khonkaen/posts/18551  ทาวน์โฮม  มั่นใจ  1980000.0
# 236   2  https://nayoo.co/khonkaen/posts/19434  ทาวน์โฮม  มั่นใจ  2000000.0
# 237   2  https://nayoo.co/khonkaen/posts/19501  ทาวน์โฮม  มั่นใจ  1790000.0
# 238   2  https://nayoo.co/khonkaen/posts/20367  ทาวน์โฮม  มั่นใจ  1590000.0
#
# ...

# %%
data5= pd.read_excel('/content/drive/MyDrive/2 65/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='อาคารพาณิชย์',skiprows=1)
data5
# Out:
#     01    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน  มั่นใจ  \
# 0    2    https://nayoo.co/khonkaen/posts/6  อาคารพาณิชย์/สำนักงาน  มั่นใจ
# 1    1   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน  มั่นใจ
# 2    2   https://nayoo.co/khonkaen/posts/17  อาคารพาณิชย์/สำนักงาน  มั่นใจ
# 3    1   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน  มั่นใจ
# 4    2   https://nayoo.co/khonkaen/posts/21  อาคารพาณิชย์/สำนักงาน  มั่นใจ
# 5    1   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน  มั่นใจ
# 6    2   https://nayoo.co/khonkaen/posts/22  อาคารพาณิชย์/สำนักงาน  มั่นใจ
# 7    1   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน  มั่นใจ
# 8    2   https://nayoo.co/khonkaen/posts/24  อาคารพาณิชย์/สำนักงาน  มั่นใจ
# 9    1   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน  มั่นใจ
# 10   2   https://nayoo.co/khonkaen/posts/30  อาคารพาณิชย์/สำนักงาน  มั่นใจ
# ...

# %%
data6= pd.read_excel('/content/drive/MyDrive/2 65/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='secondhand',skiprows=1)
data6
# Out:
#          1.0       https://nayoo.co/khonkaen/posts/1     390000.0  \
# 0        4.0       https://nayoo.co/khonkaen/posts/4     820000.0
# 1        6.0       https://nayoo.co/khonkaen/posts/6    7000000.0
# 2        7.0       https://nayoo.co/khonkaen/posts/7     710000.0
# 3        9.0       https://nayoo.co/khonkaen/posts/9   13000000.0
# 4       11.0      https://nayoo.co/khonkaen/posts/11   17000000.0
# ...      ...                                     ...          ...
# 3719  20466P  https://nayoo.co/khonkaen/posts/20466P     910000.0
# 3720  30358P  https://nayoo.co/khonkaen/posts/30358P     650000.0
# 3721  30359P  https://nayoo.co/khonkaen/posts/30359P    3000000.0
# 3722  30360P  https://nayoo.co/khonkaen/posts/30360P    3980000.0
# 3723  30362P  https://nayoo.co/khonkaen/posts/30362P  343050000.0
#
#                  บ้านเดี่ยว
# 0                บ้านเดี่ยว
# 1     อาคารพาณิชย์/สำนักงาน
# 2                    ที่ดิน
# 3                    ที่ดิน
# ...

# %%
data7= pd.read_excel('/content/drive/MyDrive/2 65/bsc_DPDM_data/คำตอบนักประเมิน.xlsx',sheet_name='ชีต8',skiprows=1)
data7
# Out:
#    2      ขายได้ ใช้ระยะเวลา 4-6 เดือน
# 0  3     ขายได้ ใช้ระยะเวลา 7-12 เดือน
# 1  4  ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี
# 2  5                   ขายไม่ได้แน่นอน
